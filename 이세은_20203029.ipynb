# %% [markdown]
# # 1.(a)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# filename = "C:/Users/user/seun/3-1 교과목 빅데이터분석/경상남도_창원시_공장등록현황_20210831.csv"
# with open(filename, 'rb') as f:
#     result = chardet.detect(f.readline())  
#     print(result['encoding'])

# %%
df = pd.read_csv("경상남도_창원시_공장등록현황_20210831.csv", encoding='UTF-8-SIG')
df
# Out:
#         순번                 회사명  \
# 0        1  (사)한국장애인사회복지회사회복지부
# 1        2         (윈펠)WINPELL
# 2        3         (유)국제보링1급정비
# 3        4            (유)두루산업사
# 4        5            (유)리앤리테크
# ...    ...                 ...
# 4569  4570                희성테크
# 4570  4571             히트케이(주)
# 4571  4572               히팅플러스
# 4572  4573             힐데갈드화장품
# 4573  4574                힘멜테크
#
#                                                  공장대표주소  \
# 0                           경상남도 창원시 진해구 웅천동로 204 (성내동)
# 1                         경상남도 창원시 성산구 연덕로27번길 60 (웅남동)
# 2               경상남도 창원시 마산회원구 내서읍 중리공단로 149 (현대자동차서비스)
# 3              경상남도 창원시 마산회원구 봉암공단9길 10 (봉암동, (유)두루산업사)
# 4                       경상남도 창원시 성산구 반월로 16 (신촌동) 외 2필지
# ...                                                 ...
# 4569                경상남도 창원시 성산구 월림로67번길 5 (신촌동, 신촌동공장)
# 4570  경상남도 창원시 마산합포구 3·15대로 298, 504호(서성동, 경남대학교 창업보육관)
# 4571     경상남도 창원시 성산구 완암로 50, 넥스동 7층 705 (성산동, SK테크노파크)
# ...

# %%
df = df.drop(['순번','전화번호','팩스번호'], axis = 1)
df
# Out:
#                      회사명                                             공장대표주소  \
# 0     (사)한국장애인사회복지회사회복지부                        경상남도 창원시 진해구 웅천동로 204 (성내동)
# 1            (윈펠)WINPELL                      경상남도 창원시 성산구 연덕로27번길 60 (웅남동)
# 2            (유)국제보링1급정비            경상남도 창원시 마산회원구 내서읍 중리공단로 149 (현대자동차서비스)
# 3               (유)두루산업사           경상남도 창원시 마산회원구 봉암공단9길 10 (봉암동, (유)두루산업사)
# 4               (유)리앤리테크                    경상남도 창원시 성산구 반월로 16 (신촌동) 외 2필지
# ...                  ...                                                ...
# 4569                희성테크                경상남도 창원시 성산구 월림로67번길 5 (신촌동, 신촌동공장)
# 4570             히트케이(주)  경상남도 창원시 마산합포구 3·15대로 298, 504호(서성동, 경남대학교 창업보육관)
# 4571               히팅플러스     경상남도 창원시 성산구 완암로 50, 넥스동 7층 705 (성산동, SK테크노파크)
# 4572             힐데갈드화장품           경상남도 창원시 의창구 차룡로48번길 44 (팔용동) 1동 5층 505호
# 4573                힘멜테크     경상남도 창원시 성산구 완암로 50, 테크동 9층 913 (성산동, SK테크노파크)
#
#                              업종명                   생산품
# ...

# %%
address = df['공장대표주소']

gu = ['성산구', '의창구', '마산합포구', '마산회원구', '진해구']
num_factory = np.zeros(5)
for x in range(5):
    tmp = address.str.contains(gu[x]).value_counts()
    num_factory[x] = tmp[1]
    print(tmp[1]) #true인것만해서 0이 아니라 1임.
    
np.sum(num_factory)

gulist = address.str.split('\s+')
gu = [len(gulist)]

for x in range(len(gulist)):
    gu = gulist[x][2]
    print(gu)

df['구'] = gulist
# np.sum(num_factory)
# gulist = df.공장대표주소.str[9:12].tolist()
# gulist
# address.str.contains('의창구').value_counts()
# Out:
# 1753
# 1252
# 395
# 890
# 284
# 진해구
# 성산구
# 마산회원구
# 마산회원구
# 성산구
# 의창구
# 성산구
# 마산합포구
# 마산회원구
# 의창구
# 마산합포구
# 마산회원구
# 마산회원구
# 마산회원구
# 마산회원구
# 마산회원구
# 마산회원구
# 마산회원구
# 마산회원구
# 마산회원구
# 진해구
# 마산회원구
# 마산회원구
# 마산합포구
# 성산구
# 마산회원구
# 의창구
# 마산회원구
# 성산구
# 의창구
# 성산구
# 의창구
# 마산회원구
# 의창구
# 마산회원구
# 마산합포구
# 마산회원구
# 마산회원구
# 의창구
# 의창구
# 마산회원구
# 의창구
# 의창구
# 마산회원구
# 성산구
# 마산합포구
# 마산회원구
# 성산구
# 성산구
# 마산회원구
# 성산구
# 마산합포구
# 마산합포구
# 성산구
# 의창구
# 성산구
# 성산구
# 성산구
# 의창구
# 마산회원구
# 마산합포구
# 의창구
# 마산회원구
# 마산회원구
# 의창구
# 성산구
# 마산합포구
# 마산합포구
# 성산구
# 진해구
# 마산회원구
# 의창구
# 마산합포구
# 성산구
# 성산구
# 의창구
# 의창구
# 성산구
# 마산합포구
# 성산구
# 마산합포구
# 마산회원구
# 마산합포구
# 마산합포구
# 마산합포구
# 진해구
# 성산구
# 의창구
# 의창구
# 성산구,
# 성산구
# 마산합포구
# 성산구
# 마산회원구
# 의창구
# 마산합포구
# 마산회원구
# 마산회원구
# 의창구
# 의창구
# 마산합포구
# 의창구
# 마산합포구
# 마산회원구
# 의창구
# 성산구
# 의창구
# 성산구
# 성산구
# 성산구
# 성산구
# 성산구
# 성산구
# 의창구
# 의창구
# 의창구
# 마산합포구
# 마산합포구
# 성산구
# 마산합포구
# 마산회원구
# 성산구
# 의창구
# 진해구
# 진해구
# 마산회원구
# 성산구
# 마산합포구
# 성산구
# 마산회원구
# 의창구
# 의창구
# 성산구
# 의창구
# 의창구
# 의창구
# 성산구
# 의창구
# 의창구
# 의창구
# 의창구
# ...

# %%
# Number_Factory_Gu = pd.Series(num_factory, index=gu)
# Number_Factory_Gu
# df['구'] = gulist
# gulist
df['구']
# num_factory
# Out:
# 0                      [경상남도, 창원시, 진해구, 웅천동로, 204, (성내동)]
# 1                    [경상남도, 창원시, 성산구, 연덕로27번길, 60, (웅남동)]
# 2         [경상남도, 창원시, 마산회원구, 내서읍, 중리공단로, 149, (현대자동차서비스)]
# 3        [경상남도, 창원시, 마산회원구, 봉암공단9길, 10, (봉암동,, (유)두루산업사)]
# 4                [경상남도, 창원시, 성산구, 반월로, 16, (신촌동), 외, 2필지]
#                               ...
# 4569          [경상남도, 창원시, 성산구, 월림로67번길, 5, (신촌동,, 신촌동공장)]
# 4570    [경상남도, 창원시, 마산합포구, 3·15대로, 298,, 504호(서성동,, 경남...
# 4571    [경상남도, 창원시, 성산구, 완암로, 50,, 넥스동, 7층, 705, (성산동,...
# 4572    [경상남도, 창원시, 의창구, 차룡로48번길, 44, (팔용동), 1동, 5층, 5...
# 4573    [경상남도, 창원시, 성산구, 완암로, 50,, 테크동, 9층, 913, (성산동,...
# Name: 구, Length: 4574, dtype: object

# %%
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/gulim.ttc"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

# %%
df['구'].value_counts()
# Out:
# 성산구    1753
# 의창구    1252
# 마산회     890
# 마산합     395
# 진해구     284
# Name: 구, dtype: int64

# %% [markdown]
# # 1.(b)

# %%
fig = plt.figure()
axis1 = fig.add_subplot(1, 1, 1)

axis1.hist(df['구'])
plt.show()

# %%
# dff =df.div(df.sum(1), axis=0) #각 로우의 합이 1이되도록 정규화하고 그래프를 그려본다.
# dff

# %%
# df['구'].plot.pie()
# plt.show()

# %%
plt.pie(df['구'].value_counts(), autopct='%.1f%%')
plt.show()

# %%
# df.plot.pie(color='k', alpha=0.7, subplots=True)

# %% [markdown]
# # 2. (a)

# %%
import chardet

# %%
filename = "C:/Users/user/seun/3-1 교과목 빅데이터분석/서울일자리센터 인재정보 직종별, 지역별 목록.csv"
with open(filename, 'rb') as f:
    result = chardet.detect(f.readline())  
    print(result['encoding'])
# Out:
# EUC-KR

# %%
ddf = pd.read_csv("C:/Users/user/seun/3-1 교과목 빅데이터분석/서울일자리센터 인재정보 직종별, 지역별 목록.csv", encoding = 'EUC-KR')
ddf.head()
# Out:
#              구직신청번호 성별  나이  학력공통코드 학력공통코드명 희망근무지역(시도)_1 희망근무지역명(시군구)_1  \
# 0  H128202107071973  남  74  J00106    고등학교           서울            강북구
# 1  H309202107071965  남  87  J00100    관계없음           서울            강북구
# 2  H110202107071953  여  68  J00100    관계없음           서울            서초구
# 3  H318202107071951  남  30  J00106    고등학교           서울            금천구
# 4  H129202107071950  여  66  J00106    고등학교           서울            송파구
#
#   희망근무지역명(시도)_2 희망근무지역명(시군구)_2  희망직종공통코드  ... 희망직종경력년_월수  구직인증상태공통구분  \
# 0            서울            NaN    814001  ...       6년0월      J03402
# 1           NaN            NaN    561100  ...         신입      J03402
# 2            서울            강남구    561101  ...         신입      J03402
# 3           NaN            NaN    622301  ...         신입      J03402
# 4            서울            NaN    561101  ...       3년0월      J03402
#
#    구직인증상태공통구분명 검색키워드1 검색키워드2 검색키워드3 검색키워드4 검색키워드5     등록일시     수정일시
# ...

# %%
ddf.describe()
# Out:
#                 나이       희망직종공통코드    희망직종경력년수   희망직종경력개월수
# count  1356.000000    1356.000000  801.000000  801.000000
# mean     57.960914  500903.948378    6.398252    1.188514
# std      12.513695  199919.735355    7.711190    2.470965
# min      17.000000   12200.000000    0.000000    0.000000
# 25%      54.000000  542000.000000    1.000000    0.000000
# 50%      61.000000  550104.000000    4.000000    0.000000
# 75%      66.000000  561101.000000   10.000000    0.000000
# max      87.000000  905002.000000   44.000000   11.000000

# %%
fig = plt.figure()
axis1 = fig.add_subplot(1, 1, 1)

axis1.hist(ddf['성별'])
plt.show()

# %%
plt.pie(ddf['성별'].value_counts(), autopct='%.1f%%')
plt.show()

# %% [markdown]
# # 2.(b)

# %%
age = []
ddf[ddf['나이'] >= 80]
# Out:
#                구직신청번호 성별  나이  학력공통코드 학력공통코드명 희망근무지역(시도)_1 희망근무지역명(시군구)_1  \
# 1    H309202107071965  남  87  J00100    관계없음           서울            강북구
# 33   H121202107071757  남  80  J00106    고등학교           서울            중랑구
# 311  H307202107070492  여  84  J00102    초등학교           서울            중랑구
# 425  H311202107061880  남  80  J00102    초등학교           서울            노원구
# 468  H311202107061667  여  83  J00102    초등학교           서울            노원구
# 681  H321202107060635  남  82  J00106    고등학교           서울            관악구
#
#     희망근무지역명(시도)_2 희망근무지역명(시군구)_2  희망직종공통코드  ... 희망직종경력년_월수  구직인증상태공통구분  \
# 1             NaN            NaN    561100  ...         신입      J03402
# 33             서울            NaN    624102  ...       3년0월      J03402
# 311            서울            NaN    561100  ...         신입      J03402
# 425            서울            도봉구    561101  ...       3년0월      J03402
# 468            서울            NaN    561100  ...         신입      J03402
# ...

# %%
ddf[ddf['나이'] >= 70]
# Out:
#                 구직신청번호 성별  나이  학력공통코드 학력공통코드명 희망근무지역(시도)_1 희망근무지역명(시군구)_1  \
# 0     H128202107071973  남  74  J00106    고등학교           서울            강북구
# 1     H309202107071965  남  87  J00100    관계없음           서울            강북구
# 10    H127202107071898  남  71  J00106    고등학교           서울            광진구
# 33    H121202107071757  남  80  J00106    고등학교           서울            중랑구
# 34    H325202107071756  여  72  J00104     중학교           서울            강동구
# ...                ... ..  ..     ...     ...          ...            ...
# 1202  H111202107050467  여  79  J00100    관계없음           서울           동대문구
# 1209  H130202107050399  여  71  J00102    초등학교           서울            금천구
# 1219  H130202107050327  남  77  J00106    고등학교           서울            금천구
# 1282  H322202107010618  여  71  J00104     중학교           서울            서초구
# 1334  H309202105120722  남  71  J00102    초등학교           서울            강북구
#
#      희망근무지역명(시도)_2 희망근무지역명(시군구)_2  희망직종공통코드  ... 희망직종경력년_월수  구직인증상태공통구분  \
# ...

# %%
# agelist = ddf.나이.str[0:1].tolist()
# agelist

# %% [markdown]
# # 2.(c)

# %%
fig = plt.figure()
axis1 = fig.add_subplot(1, 1, 1)

axis1.hist(ddf['학력공통코드명'])
plt.show()

# %%
guzic = (ddf['학력공통코드명'] != '중학교') & (ddf['학력공통코드명'] != '초등학교')
guzic
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1351    False
# 1352    False
# 1353     True
# 1354     True
# 1355     True
# Name: 학력공통코드명, Length: 1356, dtype: bool

# %%
gulist = ddf.희망직종경력년_월수.str[0:2].tolist()
gulist
# Out:
# ['6년',
#  '신입',
#  '신입',
#  '신입',
#  '3년',
#  '0년',
#  '신입',
#  '2년',
#  '신입',
#  '10',
#  '2년',
#  '1년',
#  '1년',
#  '4년',
#  '신입',
#  '10',
#  '4년',
#  '8년',
#  '신입',
#  '1년',
#  '3년',
#  '30',
#  '0년',
#  '2년',
#  '신입',
#  '2년',
#  '2년',
#  '신입',
#  '15',
#  '1년',
#  '4년',
#  '신입',
#  '신입',
#  '3년',
#  '신입',
#  '신입',
#  '신입',
#  '신입',
#  '4년',
#  '4년',
#  '신입',
#  '신입',
#  '6년',
#  '30',
#  '신입',
#  '5년',
#  '3년',
#  '5년',
#  '3년',
#  '신입',
#  '0년',
#  '신입',
#  '9년',
#  '1년',
#  '2년',
#  '신입',
#  '3년',
#  '신입',
#  '42',
#  '1년',
#  '신입',
#  '신입',
#  '10',
#  '신입',
#  '11',
#  '3년',
#  '신입',
#  '40',
#  '10',
#  '신입',
#  '2년',
#  '5년',
#  '신입',
#  '0년',
#  '7년',
#  '10',
#  '신입',
#  '10',
#  '1년',
#  '신입',
#  '6년',
#  '1년',
#  '10',
#  '신입',
#  '4년',
#  '3년',
#  '5년',
#  '20',
#  '신입',
#  '신입',
#  '6년',
#  '신입',
#  '신입',
#  '신입',
#  '20',
#  '4년',
#  '1년',
#  '2년',
#  '신입',
#  '5년',
#  '신입',
#  '신입',
#  '3년',
#  '신입',
#  '0년',
#  '신입',
#  '12',
#  '1년',
#  '신입',
#  '10',
#  '0년',
# ...

# %%
inlist = ddf.희망직종경력년_월수.str.contains('1년').tolist()
inlist2 = ddf.희망직종경력년_월수.str.contains('2년').tolist()
inlist3 = ddf.희망직종경력년_월수.str.contains('3년').tolist()
inlist4 = ddf.희망직종경력년_월수.str.contains('4년').tolist()
inlist5 = ddf.희망직종경력년_월수.str.contains('신입').tolist()

for i in range(1356):
    if inlist[i] == True:
        inlist[i] = '신입'
        
for i in range(1356):
    if inlist2[i] == True:
        inlist[i] = '신입'
        
for i in range(1356):
    if inlist3[i] == True:
        inlist[i] = '신입'
        
for i in range(1356):
    if inlist4[i] == True:
        inlist[i] = '신입'
        
for i in range(1356):
    if inlist5[i] == True:
        inlist[i] = '신입'
        
for i in range(1356):
    if inlist[i] == False:
        inlist[i] = '5년이상경력'

# %%
inlist
# Out:
# ['5년이상경력',
#  '신입',
#  '신입',
#  '신입',
#  '신입',
#  '5년이상경력',
#  '신입',
#  '신입',
#  '신입',
#  '5년이상경력',
#  '신입',
#  '신입',
#  '신입',
#  '신입',
#  '신입',
#  '5년이상경력',
#  '신입',
#  '5년이상경력',
#  '신입',
#  '신입',
#  '신입',
#  '5년이상경력',
#  '5년이상경력',
#  '신입',
#  '신입',
#  '신입',
#  '신입',
#  '신입',
#  '5년이상경력',
#  '신입',
#  '신입',
#  '신입',
#  '신입',
#  '신입',
#  '신입',
#  '신입',
#  '신입',
#  '신입',
#  '신입',
#  '신입',
#  '신입',
#  '신입',
#  '5년이상경력',
#  '5년이상경력',
#  '신입',
#  '5년이상경력',
#  '신입',
#  '5년이상경력',
#  '신입',
#  '신입',
#  '5년이상경력',
#  '신입',
#  '5년이상경력',
#  '신입',
#  '신입',
#  '신입',
#  '신입',
#  '신입',
#  '신입',
#  '신입',
#  '신입',
#  '신입',
#  '5년이상경력',
#  '신입',
#  '신입',
#  '신입',
#  '신입',
#  '5년이상경력',
#  '5년이상경력',
#  '신입',
#  '신입',
#  '5년이상경력',
#  '신입',
#  '5년이상경력',
#  '5년이상경력',
#  '5년이상경력',
#  '신입',
#  '5년이상경력',
#  '신입',
#  '신입',
#  '5년이상경력',
#  '신입',
#  '5년이상경력',
#  '신입',
#  '신입',
#  '신입',
#  '5년이상경력',
#  '5년이상경력',
#  '신입',
#  '신입',
#  '5년이상경력',
#  '신입',
#  '신입',
#  '신입',
#  '5년이상경력',
#  '신입',
#  '신입',
#  '신입',
# ...

# %%
# guzic2 = ddf['희망직종경력년_월수'] != '신입' & ddf['희망직종경력년_월수'] != '신입'

# %%
ddf['경력여부'] = inlist

# %%
ddf
# Out:
#                 구직신청번호 성별  나이  학력공통코드 학력공통코드명 희망근무지역(시도)_1 희망근무지역명(시군구)_1  \
# 0     H128202107071973  남  74  J00106    고등학교           서울            강북구
# 1     H309202107071965  남  87  J00100    관계없음           서울            강북구
# 2     H110202107071953  여  68  J00100    관계없음           서울            서초구
# 3     H318202107071951  남  30  J00106    고등학교           서울            금천구
# 4     H129202107071950  여  66  J00106    고등학교           서울            송파구
# ...                ... ..  ..     ...     ...          ...            ...
# 1351  H001202104121072  여  54  J00102    초등학교           서울            도봉구
# 1352  H310202104090587  여  61  J00104     중학교           서울            도봉구
# 1353  H001202101250403  여  47  J00110  대학_대학교           서울             전체
# 1354  H001202101250036  여  47  J00108    전문대학           서울            노원구
# 1355  H001202101182829  여  23  J00108    전문대학           경기            NaN
#
#      희망근무지역명(시도)_2 희망근무지역명(시군구)_2  희망직종공통코드  ... 구직인증상태공통구분  구직인증상태공통구분명  \
# ...

# %%
guzic = (ddf['학력공통코드명'] != '중학교') & (ddf['학력공통코드명'] != '초등학교') & (ddf['경력여부'] == '5년이상경력')
guzic
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1351    False
# 1352    False
# 1353     True
# 1354    False
# 1355    False
# Length: 1356, dtype: bool

# %%
ddf['경력여부'].value_counts()
# Out:
# 신입        949
# 5년이상경력    407
# Name: 경력여부, dtype: int64

# %%
ddf['최종'] = guzic

# %%
ddf
# Out:
#                 구직신청번호 성별  나이  학력공통코드 학력공통코드명 희망근무지역(시도)_1 희망근무지역명(시군구)_1  \
# 0     H128202107071973  남  74  J00106    고등학교           서울            강북구
# 1     H309202107071965  남  87  J00100    관계없음           서울            강북구
# 2     H110202107071953  여  68  J00100    관계없음           서울            서초구
# 3     H318202107071951  남  30  J00106    고등학교           서울            금천구
# 4     H129202107071950  여  66  J00106    고등학교           서울            송파구
# ...                ... ..  ..     ...     ...          ...            ...
# 1351  H001202104121072  여  54  J00102    초등학교           서울            도봉구
# 1352  H310202104090587  여  61  J00104     중학교           서울            도봉구
# 1353  H001202101250403  여  47  J00110  대학_대학교           서울             전체
# 1354  H001202101250036  여  47  J00108    전문대학           서울            노원구
# 1355  H001202101182829  여  23  J00108    전문대학           경기            NaN
#
#      희망근무지역명(시도)_2 희망근무지역명(시군구)_2  희망직종공통코드  ... 구직인증상태공통구분명  검색키워드1  검색키워드2  \
# ...

# %%
ddf[ddf['최종'] == True]
# Out:
#                 구직신청번호 성별  나이  학력공통코드 학력공통코드명 희망근무지역(시도)_1 희망근무지역명(시군구)_1  \
# 0     H128202107071973  남  74  J00106    고등학교           서울            강북구
# 5     H108202107071928  여  63  J00106    고등학교           서울           서대문구
# 9     H129202107071899  남  63  J00106    고등학교           서울            송파구
# 15    H311202107071854  남  54  J00106    고등학교           서울            노원구
# 21    H307202107071829  여  55  J00106    고등학교           서울            중랑구
# ...                ... ..  ..     ...     ...          ...            ...
# 1342  H001202104280192  남  56  J00108    전문대학           서울             중구
# 1345  H001202104231487  남  50  J00106    고등학교           서울             전체
# 1349  H306202104131663  여  66  J00106    고등학교           서울           동대문구
# 1350  H324202104121333  남  60  J00108    전문대학           서울            송파구
# 1353  H001202101250403  여  47  J00110  대학_대학교           서울             전체
#
#      희망근무지역명(시도)_2 희망근무지역명(시군구)_2  희망직종공통코드  ... 구직인증상태공통구분명  검색키워드1   검색키워드2  \
# ...
