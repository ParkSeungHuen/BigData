# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('경상남도_창원시_공장등록현황_20210831.csv', encoding='UTF-8-SIG')
data = data['공장대표주소']

# %%
plt.plot(data)
# Out:
# C:\Users\PARKSEUNGHEUN\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 44221 (\N{HANGUL SYLLABLE GYEONG}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\PARKSEUNGHEUN\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\PARKSEUNGHEUN\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\PARKSEUNGHEUN\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   func(*args, **kwargs)
# ...

# %%
data
# Out:
# 0                             경상남도 창원시 진해구 웅천동로 204 (성내동)
# 1                           경상남도 창원시 성산구 연덕로27번길 60 (웅남동)
# 2                 경상남도 창원시 마산회원구 내서읍 중리공단로 149 (현대자동차서비스)
# 3                경상남도 창원시 마산회원구 봉암공단9길 10 (봉암동, (유)두루산업사)
# 4                         경상남도 창원시 성산구 반월로 16 (신촌동) 외 2필지
#                               ...
# 4569                  경상남도 창원시 성산구 월림로67번길 5 (신촌동, 신촌동공장)
# 4570    경상남도 창원시 마산합포구 3·15대로 298, 504호(서성동, 경남대학교 창업보육관)
# 4571       경상남도 창원시 성산구 완암로 50, 넥스동 7층 705 (성산동, SK테크노파크)
# 4572             경상남도 창원시 의창구 차룡로48번길 44 (팔용동) 1동 5층 505호
# 4573       경상남도 창원시 성산구 완암로 50, 테크동 9층 913 (성산동, SK테크노파크)
# Name: 공장대표주소, Length: 4574, dtype: object
